# %%
from deeplenstronomy.Simulations.lenstronomy_sim import LenstronomySim
lenstronomy_sim = LenstronomySim()

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
lenstronomySim = LenstronomySim()
kwargs_lens = [{'theta_E': 0.5, 'center_x': 0, 'center_y': 0}]
kwargs_source = [{'amp': 10, 'R_sersic': 1, 'n_sersic': 1, 'center_x': 0.1, 'center_y': 0}]
kwargs_lens_light = [{'amp': 1, 'R_sersic': 2, 'n_sersic': 4, 'center_x': 0., 'center_y': 0}]
numpix = 100
pixelscale = 0.03
model = lenstronomySim.simulate_sis_sersic(kwargs_lens, kwargs_source, kwargs_lens_light, numpix, pixelscale, psf_image=None)

plt.matshow(model, origin='lower')
plt.show()
